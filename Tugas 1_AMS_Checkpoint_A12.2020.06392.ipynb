# %% [markdown]
# ## Eksperimen dan Pengumpulan Dataset

# %% [markdown]
# ## Pemanggilan Library

# %%
import pandas as pd
import time
import tweepy
import numpy as np

# %%
def twitter_config():
    """
    Fungsi utilitas untuk mengkonfigurasi konsumsi file API Twitter dengan␣
    ,!kunci yang disediakan.
    """
    
    # Autentikasi dan akses menggunakan keys
    auth = tweepy.OAuthHandler("918jGk0FXin1RU7TGrXQNhEVS", 
    "MUtmQOmbKVmYUS2Aq0spOPOdMQsdqzTYf82EYUGW8dbtTGbRAR")
    auth.set_access_token("1574652392255021057-nvMImJSpDnyuO2DfNIRPxEHxjjsYD5", 
    "rs9Eb0vcn7291OflCzcYtclHMpg61WZkldsmwDSy0hFHS")
    
    # Kembalikan akses ke API
    api = tweepy.API(auth)
    try:
        api.verify_credentials()
        print("Authentication OK")
    except:
        print("Error during authentication")
    return api

# %%
# Membuat extractor object
extractor = twitter_config()
# Out:
# Error during authentication

# %% [markdown]
# ## Ambil Tweet Dari Username
# username yang saya gunakan adalah @FiersaBesari

# %%
tweets = extractor.user_timeline(screen_name="FiersaBesari", count=1000)
print("Tweets terambil: {}.\n".format(len(tweets)))

print("100 tweet teratas:\n")
for tweet in tweets[:100]:
    print(tweet.text)
    print()
# Out:
# Tweets terambil: 200.
#
# 100 tweet teratas:
#
# @ngurahhh_ Perih, Gan
#
# @menteriwakanda Kolom ijo
#
# Kamu adalah kolom chat yang aku abadikan. Aku adalah kolom chat yang kamu hapus
#
# Tuhan enggak selalu memudahkan. Bisa aja jalannya dipersulit, tapi kitanya yang dikuatkan
#
# @ardibhironx Protips: Klik gambar jpeg yang tersedia di akunnya, terus slide ke kiri/kanan ke arah video. Slide lag… https://t.co/e5gsfS8XSt
#
# Tapi, bukankah hidup ini adalah perjuangan? https://t.co/rxQFYd0mjr
#
# Sesedih-sedihnya kisah hidupmu, masih lebih sedih flashback Naruto https://t.co/zk1dMl59qu
#
# Memperingati 20 tahun Naruto ketika beli efek gitar. Lagu apakah ini? https://t.co/ZXA8BS4L0t
#
# Orang-orang tahunya, “Enak banget sih hidup lu.” Tapi mereka tidak tahu perjuangan panjang yang tak sempat di-instastory-kan
#
# Sepertinya memang perlu menutup diri. Makin terbuka makin rentan terluka
#
# @TheRainBand Akhirnya di-notice 🥺
#
# @KuntoAjiW Gepeng
#
# @alonkii Eh, GPU deng wkwk
#
# @alonkii VGA? 👀👀
#
# @handokotjung Hei hei hei
#
# “Bukankah kita pernah berjanji, tak akan sesali kisah ini?”
#
# — The Rain
# .
# Menurut saya, ini lagu terbaik The Rain s… https://t.co/or0m55wH6o
#
# Aku + kegabutanku = Hasrat belanja online tiada henti 😩
#
# Woi!
#
# https://t.co/BpGGE1qd3B
#
# @ffuhfuhhfiuhh Wkwk. Mana pada lama banget nangkepnya
#
# @Restif28_ Edans
#
# @owalahmon Cintailah manusia gepeng. Hanya mereka yang mampu mengerti kepedihanku
#
# Berhubung tumben-tumbenan pakai batik https://t.co/REHu2tdx7Q
#
# Jangan baper - udah tahu ujungnya kayak gimana - jangan baper - udah tahu ujungnya kayak gimana - Jangan baper - ud… https://t.co/JXWMLIREiM
#
# “Mengutuki diri, tak bisa kembali tuk mengubah alur kisah”
# .
# Panggung yang paling tidak bisa ceria. Setengah energi… https://t.co/TQ0UyCQ1jh
#
# Sepak bola tidak seharusnya semenyakitkan ini
#
# Bagi dunia, mungkin kelak akan menjadi sekadar angka. Bagi keluarganya, akan menjadi luka seumur hidup. Inna lillah… https://t.co/GesRIWergJ
#
# “Mereka bilang syukurilah saja. Padahal rela tak semudah kata”
# .
# Hari ini tepat satu tahun lagu “Runtuh” hadir. Ter… https://t.co/1s4wUTZq5D
#
# @jek___ Tom and Jeremy Teti
#
# Lah, cocok juga 😅 https://t.co/ko88vWgjkA
#
# Banyak rencana gagal
# dan kita dipaksa rela
#
# @inayma Terima kasih, Nay. Tetap kuat di sana, seperti selalu
#
# @GigoloJKT1993 https://t.co/IdUHu0xOGy
#
# Cukup! Beritanya terlalu banyak
# .
# Otakku. Mau. Meledak
#
# @nuicemedia @teppy87 Tepat seberes kami perpanjang paspor bulan kemarin 🥲
#
# @adnannslmn Fans Mursyid mari berkumpul 🙋🏻‍♂️
#
# Kamu suka yang konsrang-konsreng, aku suka yang gonjrang-gonjreng. Cakep. Udah tahu red flag dan banyak nyeleweng,… https://t.co/iTk72m9SAx
#
# Seberes trauma, bukannya tambah kuat, malah takut memulai sesuatu
#
# Agar lebih maksimal dalam memberi kode, video lirik “Pengecut” sudah bisa dinikmati di Youtube. Link bisa langsung… https://t.co/7zyWhET959
#
# Sepertinya, aura wibu di lagu “Pengecut” teramat kuat …. https://t.co/I0QLFSf6ZF
#
# Terima kasih banyak antusiasmenya, Kawan-kawan. Bahagia sekali ❤️
#
# @ElogueendMbak Gas dong
#
# @_suryamoch Mungkin. Bentar saya tanya Pak RT dulu
#
# @lelahlesulovyu Terima kasih 🙏🏼❤️
#
# “Pada siapa kau mengeluh, jika bukan kepadaku? Setengah mati diriku, setengah hati dirimu”
# .
# Lagu “Pengecut” sudah… https://t.co/4EOiw9NX6k
#
# Kirain diri ini sudah pulih. Ternyata masih ada satu kenangan buruk yang ketika dikorek-korek bikin merinding, mual, dan sakit di ulu hati
#
# @Chokieee_ Lho, kan memang
#
# @gewmuyy Elu-elu
#
# Hidup sudah rumit sedari chat whatsapp
#
# Besok, di berbagai platform digital. Sudah siap? https://t.co/mEAFKC4zXS
#
# @christiyanoktw Mestakung. Semesta suka menikung
#
# Biarkan semesta bekerja, karena aku malas bekerja
#
# @oendari Tapi takut jadi PG-13. Tapi hyped up. Tapi Disney. Tapi … dah ah mau rewacth Naruto lagi aja
#
# Aku:
# MCU sekarang udah enggak kayak dulu. Enggak usah nge-hype lagi
#
# Aku pas lihat Hugh Jackman mau balik jadi Wolv… https://t.co/a6IwyE71Vj
#
# Cuma bisa saling mengingat,
# tapi bukan saling mengikat
#
# @fannysoegi Udah nyiapin daftar rekomendasi buku untuk dibeli, nih
#
# @Chokieee_ Sebagai bapak, harus siap-siap nemenin anak naik macan-macanan di mall 🥲
#
# @riefrmn Tetap bukan alasan, sih. Mendingan enggak usah jadi mendakinya
#
# Nasib anak bagaimana orang tuanya, itu betul. Tapi, patut diingat, kegiatan di alam terbuka memiliki risiko besar.… https://t.co/OsIkZtCBx9
#
# Dulu, sebelum punya anak, saya juga bercita-cita membawa anak mendaki. Tapi, ketika Neng Kinasih lahir, impian itu… https://t.co/YVRTr1rtKD
#
# @Androngehe WINDAH gebok ni
#
# Percayalah, serumit-rumitnya kisah cintamu, lebih rumit mindahin file dari iPhone ke Windows 🥲
#
# Sepertinya kita sedang adu ilmu. Kuat-kuatan enggak menyapa duluan
#
# Eh, malah jadi arang 🥲
#
# Ide nama anak, “Atang”. Jadi kalau orang typo pas manggil namanya, jadi ayang
#
# The art of wleowleowleo
#
# Bocoran lagu “Pengecut” sudah di-upload di TikTok. Pakai sound-nya, yuk. Ramaikan. Sekalian kasih kode untuk gebeta… https://t.co/WQeNC1cyWy
#
# Tak perlu khawatir, ku hanya anime
#
# “Dan tunggulah aku di sana, memecahkan celengan rinduku”
# .
# Terima kasih, Pesta Pora. Terima kasih, Dulur dan Kawan-… https://t.co/Zc8fCy0bMO
#
# @unmagnetism Toblerone Utara
#
# @lelahlesulovyu Aduh, jadi malu
#
# @lf_nae Ngakak sambil bengong
#
# Kalau ngabrut artinya ngakak brutal, berarti ngabers adalah ngakak bersama. 1 hari 1 fakta baru
#
# @rfki__ Mohon maaf. Tidak akan memberikan tanggapan sebelum Lesti
#
# Siang-siang begini enaknya minum es teh sambil memantau teh tumpah tentang es teh
#
# Dulur dan Kawan-kawan Solo, sampai jumpa di Solo Batik Music Festival
# .
# 2 Oktober 2022
# .
# Tiket:… https://t.co/YMbh3ME7nA
#
# Dulur dan Kawan-kawan Bekasi, sampai ketemu di Pesta Semalam Minggu
# .
# Transera Water Park
# 1 Oktober 2022
# .
# Tiada ke… https://t.co/IPeKHu31f7
#
# Uzumaki, “ki”-nya Kinasih https://t.co/Uoq9G0QvtG
#
# 11:11
#
# @ikramarki Aku ke laklakan
#
# Jadi, dibiarkan menggantung saja?
#
# Berusaha keras merahasiakan ini sedari lama. Akhirnya sudah diperbolehkan berbagi. Kawan-kawan, Juang dan Ana akan… https://t.co/kBzPEO4DQy
#
# @desygenoveva_ Enggak usah nunggu lagi. Kamu terlambat, Cides
#
# Aduh, aduh, aduh. Minder. Sampai jumpa, Kawan-kawan. Tiada kesan tanpa kehadiranmu ❤️ https://t.co/DC4rCuGvEC
#
# @susuultrackltt Iya lagi
#
# Sepertinya, prioritas kita bukanlah bahagia, melainkan bertahan hidup. Buktinya, ada banyak hal yang bikin sakit, t… https://t.co/8V6ZXwRCnU
#
# Dipikir-pikir, dulu orang tua saya random sekali. Udah tahu orang Sunda sulit mengucapkan huruf F, eh malah, “Kasih… https://t.co/Dkv0YbUOUC
#
# Kadang, Tuhan memberi kita perasaan untuk seseorang yang enggak boleh kita sayangi. Saya cuma berharap, semoga Tuha… https://t.co/PKqPOjCKMP
#
# @oendari Diare, ya?
#
# Ingin mengabari tapi sudah tidak ditanya
#
# Enggak gampang meleyot tapi sering senyum-senyum sendiri
#
# Terlalu kepikiran untuk menunggu. Terlalu gengsi untuk menyapa duluan
#
# @lutfiah_nuaz Aamiin
#
# Maaf, baru turun gunung. Saya tertinggal berita apa?
#
# Sebuah pagi di suatu ketika https://t.co/qmaYDwJDpj
#
# @BukuMojok Yang salah bukan waktu. Tapi tukang copet. Dipanggil bukannya nyamperin, malah lari
#
# Seorang kawan nyuruh saya ingat umur. Justru karena saya ingat umur berkurang, makanya senang-senang
#
# Dulur dan Kawan-kawan Jakarta, sampai ketemu di Pesta Pora
# .
# Gambir Expo
# 25 September 2022
# .
# Tiada kesan tanpa keha… https://t.co/2ImzoEeFk4
#
# “Kau ingin kaya, hasemeleh hasemeleh hasemeleh. Kau ingin merayakan valentine tapi kubilang, ‘Sayang, valentine unt… https://t.co/rIonPhjXMZ
#
# @unmagnetism Pilihan terbaik—selain solaria—ketika harus terjebak dari bandara ke bandara
#
# @real_fahmia Di New York isuk keneh kitu?

# %% [markdown]
# ## Masukan ke dalam dataframes Pandas

# %%
# Membuat kerangka data menggunakan sintaks berikut
dataset = pd.DataFrame(data = [tweet.text for tweet in tweets], columns = ['Tweets'])

# Tampilan kerangka data
display(dataset.head(100))
# Out:
#                                                Tweets
# 0                               @ngurahhh_ Perih, Gan
# 1                           @menteriwakanda Kolom ijo
# 2   Kamu adalah kolom chat yang aku abadikan. Aku ...
# 3   Tuhan enggak selalu memudahkan. Bisa aja jalan...
# 4   @ardibhironx Protips: Klik gambar jpeg yang te...
# ..                                                ...
# 95  Seorang kawan nyuruh saya ingat umur. Justru k...
# 96  Dulur dan Kawan-kawan Jakarta, sampai ketemu d...
# 97  “Kau ingin kaya, hasemeleh hasemeleh hasemeleh...
# 98  @unmagnetism Pilihan terbaik—selain solaria—ke...
# 99          @real_fahmia Di New York isuk keneh kitu?
#
# [100 rows x 1 columns]

# %%
dataset.to_csv('dataset_FiersaBesari.csv')

# %% [markdown]
# ## Cleaning Word

# %% [markdown]
# ## Import Library untuk Cleaning Word

# %%
import pandas as pd
import re
import string
import time
from copy import deepcopy

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('dataset_FiersaBesari.csv')

df.head()
# Out:
#    Unnamed: 0                                             Tweets
# 0           0  @ardibhironx Protips: Klik gambar jpeg yang te...
# 1           1  Tapi, bukankah hidup ini adalah perjuangan? ht...
# 2           2  Sesedih-sedihnya kisah hidupmu, masih lebih se...
# 3           3  Memperingati 20 tahun Naruto ketika beli efek ...
# 4           4  Orang-orang tahunya, “Enak banget sih hidup lu...

# %%
df
# Out:
#      Unnamed: 0                                             Tweets
# 0             0  @ardibhironx Protips: Klik gambar jpeg yang te...
# 1             1  Tapi, bukankah hidup ini adalah perjuangan? ht...
# 2             2  Sesedih-sedihnya kisah hidupmu, masih lebih se...
# 3             3  Memperingati 20 tahun Naruto ketika beli efek ...
# 4             4  Orang-orang tahunya, “Enak banget sih hidup lu...
# ..          ...                                                ...
# 195         195            Belum gimana-gimana\nudah kenapa-kenapa
# 196         196          Hari yang panjang untuk tidur yang kurang
# 197         197  Pas kerja ngantuk. Pas rebahan ngantuknya hila...
# 198         198  Dulur dan Kawan-kawan Makassar. Sampai ketemu ...
# 199         199                                   @apasihpin Anjay
#
# [200 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   Tweets      200 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 3.2+ KB

# %% [markdown]
# ## Preprocessing Dataset
# Pertama lakukan instalasi modul ekphrasis

# %%
# !pip install ekphrasis
# Out:
# Requirement already satisfied: ekphrasis in c:\users\acer swift\anaconda3\lib\site-packages (0.5.4)
# Requirement already satisfied: ftfy in c:\users\acer swift\anaconda3\lib\site-packages (from ekphrasis) (6.1.1)
# Requirement already satisfied: tqdm in c:\users\acer swift\anaconda3\lib\site-packages (from ekphrasis) (4.64.0)
# Requirement already satisfied: ujson in c:\users\acer swift\anaconda3\lib\site-packages (from ekphrasis) (5.1.0)
# Requirement already satisfied: nltk in c:\users\acer swift\anaconda3\lib\site-packages (from ekphrasis) (3.7)
# Requirement already satisfied: numpy in c:\users\acer swift\anaconda3\lib\site-packages (from ekphrasis) (1.21.5)
# Requirement already satisfied: colorama in c:\users\acer swift\anaconda3\lib\site-packages (from ekphrasis) (0.4.4)
# Requirement already satisfied: matplotlib in c:\users\acer swift\anaconda3\lib\site-packages (from ekphrasis) (3.5.1)
# Requirement already satisfied: termcolor in c:\users\acer swift\anaconda3\lib\site-packages (from ekphrasis) (2.0.1)
# Requirement already satisfied: wcwidth>=0.2.5 in c:\users\acer swift\anaconda3\lib\site-packages (from ftfy->ekphrasis) (0.2.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\acer swift\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acer swift\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\acer swift\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\acer swift\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\acer swift\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer swift\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\acer swift\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\acer swift\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->ekphrasis) (1.16.0)
# Requirement already satisfied: click in c:\users\acer swift\anaconda3\lib\site-packages (from nltk->ekphrasis) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\acer swift\anaconda3\lib\site-packages (from nltk->ekphrasis) (2022.3.15)
# Requirement already satisfied: joblib in c:\users\acer swift\anaconda3\lib\site-packages (from nltk->ekphrasis) (1.1.0)

# %%
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons

text_processor = TextPreProcessor(
    # terms that will be normalized
    normalize=['email', 'percent', 'money', 'phone', 'user',
        'time', 'date', 'number'],
    # terms that will be annotated
    #annotate={"hashtag", "allcaps", "elongated", "repeated",'emphasis', 'censored'},
    annotate={"hashtag"},
    fix_html=True,  # fix HTML tokens
    
    # corpus from which the word statistics are going to be used 
    # for word segmentation 
    segmenter="twitter", 
    
    # corpus from which the word statistics are going to be used 
    # for spell correction
    corrector="twitter", 
    
    unpack_hashtags=True,  # perform word segmentation on hashtags
    unpack_contractions=True,  # Unpack contractions (can't -> can not)
    spell_correct_elong=False,  # spell correction for elongated words
    
    # select a tokenizer. You can use SocialTokenizer, or pass your own
    # the tokenizer, should take as input a string and return a list of tokens
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    
    # list of dictionaries, for replacing tokens extracted from the text,
    # with other expressions. You can pass more than one dictionaries.
    dicts=[emoticons]
)
# Out:
# C:\Users\ACER SWIFT\anaconda3\lib\site-packages\ekphrasis\classes\tokenizer.py:225: FutureWarning: Possible nested set at position 2190
#   self.tok = re.compile(r"({})".format("|".join(pipeline)))
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# Reading twitter - 1grams ...
# C:\Users\ACER SWIFT\anaconda3\lib\site-packages\ekphrasis\classes\exmanager.py:14: FutureWarning: Possible nested set at position 42
#   regexes = {k.lower(): re.compile(self.expressions[k]) for k, v in

# %%
# panggil ekphrasis

def bersih_data(text):
    return " ".join(text_processor.pre_process_doc(text))

# %%
# fungsi dari AMS 01-03. silakan cek bagaimana saya merubah menjadi fungsi

def non_ascii(text):
    return text.encode('ascii', 'replace').decode('ascii')

def remove_space(text):
    return " ".join(text.split())

def remove_emoji(text):
    return ' '.join(re.sub("([x#][A-Za-z0-9]+)"," ", text).split())

def remove_tab(text):
    return text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")

def remove_tab2(text):
    return re.sub('\s+',' ',text)

def remove_rt(text):
    return text.replace('RT'," ")

def remove_mention(text):
    return ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())

def remove_incomplete_url(text):
    return text.replace("http://", " ").replace("https://", " ")

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def change_stripe(text):
    return text.replace('-'," ")

def lower(text):
    return text.lower()

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def lower(text):
    return text.lower()

def remove_whitespace_LT(text):
    return text.strip()

def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

def remove_punctuation(text):
    remove = string.punctuation
    remove = remove.replace("_", "") # don't remove hyphens
    pattern = r"[{}]".format(remove) # create the pattern
    return re.sub(pattern, "", text)

# %%
# hapus untuk <>
def remove_number_eks(text):
    return text.replace('<number>'," ")

def remove_angka(text):
    return re.sub(r"\d+", "", text) 

def remove_URL_eks(text):
    return text.replace('URL'," ").replace('url'," ")

def space_punctuation(text):
    return re.sub('(?<! )(?=[.,!?()])|(?<=[.,!?()])(?! )', r' ', text)

# %% [markdown]
# ## Mulai Proses Pembersihan

# %%
i = 0
final_string = []
s = ""
for text in df['Tweets'].values:
    filteredSentence = []
    EachReviewText = ""
    proc = remove_rt(text)
    proc = lower(proc)
    proc = change_stripe(proc)
    proc = remove_emoji(proc)
    proc = remove_tab(proc)
    proc = remove_tab2(proc)
    proc = non_ascii(proc)
    proc = remove_incomplete_url(proc)
    proc = remove_excessive_dot(proc)
    proc = remove_whitespace_LT(proc)
    proc = remove_whitespace_multiple(proc)
    proc = remove_single_char(proc)
    proc = space_punctuation(proc)
    proc = remove_punctuation(proc)
    proc = remove_space(proc)
    proc = bersih_data(proc)
    proc = remove_number_eks(proc)
    proc = remove_angka(proc) 
    proc = remove_URL_eks(proc)
    EachReviewText = proc
    final_string.append(EachReviewText)

# %%
df["step01"] = final_string

# %%
df.head(10)
# Out:
#    Unnamed: 0                                             Tweets  \
# 0           0  @ardibhironx Protips: Klik gambar jpeg yang te...
# 1           1  Tapi, bukankah hidup ini adalah perjuangan? ht...
# 2           2  Sesedih-sedihnya kisah hidupmu, masih lebih se...
# 3           3  Memperingati 20 tahun Naruto ketika beli efek ...
# 4           4  Orang-orang tahunya, “Enak banget sih hidup lu...
# 5           5  Sepertinya memang perlu menutup diri. Makin te...
# 6           6                  @TheRainBand Akhirnya di-notice 🥺
# 7           7                                  @KuntoAjiW Gepeng
# 8           8                         @alonkii Eh, GPU deng wkwk
# 9           9                                   @alonkii VGA? 👀👀
#
#                                               step01
# 0  ardibhironx protips klik gambar jpeg yang ters...
# 1       tapi bukankah hidup ini adalah perjuangan co
# 2  sesedih sedihnya kisah hidupmu masih lebih sed...
# 3  memperingati   tahun naruto ketika beli efek g...
# 4  orang orang tahunya enak banget sih hidup lu t...
# 5  sepertinya memang perlu menutup diri makin ter...
# 6                     therainband akhirnya di notice
# 7                                   kuntoajiw gepeng
# 8                           alonkii eh gpu deng wkwk
# 9                                        alonkii vga

# %% [markdown]
# ## Hapus Data Kosong

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   Tweets      200 non-null    object
#  2   step01      200 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 4.8+ KB

# %%
df_hapus = df[~df['step01'].str.contains(" ")]

# %%
df_hapus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 130 to 174
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2 non-null      int64
#  1   Tweets      2 non-null      object
#  2   step01      2 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 64.0+ bytes

# %%
df_hapus.head(10)
# Out:
#      Unnamed: 0            Tweets        step01
# 130         130    @cankcuters ❤️    cankcuters
# 174         174  @adhitya_aria 💪🏼  adhitya_aria

# %%
df_new = df[~df.isin(df_hapus)].dropna()

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 198 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  198 non-null    float64
#  1   Tweets      198 non-null    object
#  2   step01      198 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 6.2+ KB

# %%
df_new
# Out:
#      Unnamed: 0                                             Tweets  \
# 0           0.0  @ardibhironx Protips: Klik gambar jpeg yang te...
# 1           1.0  Tapi, bukankah hidup ini adalah perjuangan? ht...
# 2           2.0  Sesedih-sedihnya kisah hidupmu, masih lebih se...
# 3           3.0  Memperingati 20 tahun Naruto ketika beli efek ...
# 4           4.0  Orang-orang tahunya, “Enak banget sih hidup lu...
# ..          ...                                                ...
# 195       195.0            Belum gimana-gimana\nudah kenapa-kenapa
# 196       196.0          Hari yang panjang untuk tidur yang kurang
# 197       197.0  Pas kerja ngantuk. Pas rebahan ngantuknya hila...
# 198       198.0  Dulur dan Kawan-kawan Makassar. Sampai ketemu ...
# 199       199.0                                   @apasihpin Anjay
#
#                                                 step01
# 0    ardibhironx protips klik gambar jpeg yang ters...
# 1         tapi bukankah hidup ini adalah perjuangan co
# 2    sesedih sedihnya kisah hidupmu masih lebih sed...
# 3    memperingati   tahun naruto ketika beli efek g...
# 4    orang orang tahunya enak banget sih hidup lu t...
# ..                                                 ...
# 195             belum gimana gimana udah kenapa kenapa
# 196          hari yang panjang untuk tidur yang kurang
# 197  pas kerja ngantuk pas rebahan ngantuknya hilan...
# 198  dulur dan kawan kawan makassar sampai ketemu d...
# 199                                    apasihpin anjay
#
# [198 rows x 3 columns]

# %% [markdown]
# ## Normalisasi Kata Slang menjadi Baku

# %%
# token
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %%
def word_tokenize_wrapper(text):
  return word_tokenize(text)

# %%
df_new['tokens'] = df["step01"].apply(word_tokenize_wrapper)

# %%
df_new.head(10)
# Out:
#    Unnamed: 0                                             Tweets  \
# 0         0.0  @ardibhironx Protips: Klik gambar jpeg yang te...
# 1         1.0  Tapi, bukankah hidup ini adalah perjuangan? ht...
# 2         2.0  Sesedih-sedihnya kisah hidupmu, masih lebih se...
# 3         3.0  Memperingati 20 tahun Naruto ketika beli efek ...
# 4         4.0  Orang-orang tahunya, “Enak banget sih hidup lu...
# 5         5.0  Sepertinya memang perlu menutup diri. Makin te...
# 6         6.0                  @TheRainBand Akhirnya di-notice 🥺
# 7         7.0                                  @KuntoAjiW Gepeng
# 8         8.0                         @alonkii Eh, GPU deng wkwk
# 9         9.0                                   @alonkii VGA? 👀👀
#
#                                               step01  \
# 0  ardibhironx protips klik gambar jpeg yang ters...
# 1       tapi bukankah hidup ini adalah perjuangan co
# 2  sesedih sedihnya kisah hidupmu masih lebih sed...
# 3  memperingati   tahun naruto ketika beli efek g...
# 4  orang orang tahunya enak banget sih hidup lu t...
# 5  sepertinya memang perlu menutup diri makin ter...
# 6                     therainband akhirnya di notice
# 7                                   kuntoajiw gepeng
# 8                           alonkii eh gpu deng wkwk
# 9                                        alonkii vga
#
#                                               tokens
# 0  [ardibhironx, protips, klik, gambar, jpeg, yan...
# 1  [tapi, bukankah, hidup, ini, adalah, perjuanga...
# 2  [sesedih, sedihnya, kisah, hidupmu, masih, leb...
# 3  [memperingati, tahun, naruto, ketika, beli, ef...
# 4  [orang, orang, tahunya, enak, banget, sih, hid...
# 5  [sepertinya, memang, perlu, menutup, diri, mak...
# 6                [therainband, akhirnya, di, notice]
# 7                                [kuntoajiw, gepeng]
# 8                     [alonkii, eh, gpu, deng, wkwk]
# 9                                     [alonkii, vga]

# %%
normalized_word = pd.read_csv('kamus_clean.csv')

# %%
normalized_word_dict = {}

for index, row in normalized_word.iterrows():
    if row[0] not in normalized_word_dict:
        normalized_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalized_word_dict[term] if term in normalized_word_dict else term for term in document]

# %%
df_new['final_tokens'] = df_new['tokens'].apply(normalized_term)

# %%
i=0
final_string_tokens = []
for text in df_new['final_tokens'].values:
    EachReviewText = ""
    EachReviewText = ' '.join(text)
    final_string_tokens.append(EachReviewText)

# %%
df_new["step02"] = final_string_tokens

# %%
df_new.head(10)
# Out:
#    Unnamed: 0                                             Tweets  \
# 0         0.0  @ardibhironx Protips: Klik gambar jpeg yang te...
# 1         1.0  Tapi, bukankah hidup ini adalah perjuangan? ht...
# 2         2.0  Sesedih-sedihnya kisah hidupmu, masih lebih se...
# 3         3.0  Memperingati 20 tahun Naruto ketika beli efek ...
# 4         4.0  Orang-orang tahunya, “Enak banget sih hidup lu...
# 5         5.0  Sepertinya memang perlu menutup diri. Makin te...
# 6         6.0                  @TheRainBand Akhirnya di-notice 🥺
# 7         7.0                                  @KuntoAjiW Gepeng
# 8         8.0                         @alonkii Eh, GPU deng wkwk
# 9         9.0                                   @alonkii VGA? 👀👀
#
#                                               step01  \
# 0  ardibhironx protips klik gambar jpeg yang ters...
# 1       tapi bukankah hidup ini adalah perjuangan co
# 2  sesedih sedihnya kisah hidupmu masih lebih sed...
# 3  memperingati   tahun naruto ketika beli efek g...
# 4  orang orang tahunya enak banget sih hidup lu t...
# 5  sepertinya memang perlu menutup diri makin ter...
# 6                     therainband akhirnya di notice
# 7                                   kuntoajiw gepeng
# 8                           alonkii eh gpu deng wkwk
# 9                                        alonkii vga
#
#                                               tokens  \
# 0  [ardibhironx, protips, klik, gambar, jpeg, yan...
# 1  [tapi, bukankah, hidup, ini, adalah, perjuanga...
# 2  [sesedih, sedihnya, kisah, hidupmu, masih, leb...
# 3  [memperingati, tahun, naruto, ketika, beli, ef...
# 4  [orang, orang, tahunya, enak, banget, sih, hid...
# 5  [sepertinya, memang, perlu, menutup, diri, mak...
# 6                [therainband, akhirnya, di, notice]
# 7                                [kuntoajiw, gepeng]
# 8                     [alonkii, eh, gpu, deng, wkwk]
# 9                                     [alonkii, vga]
#
#                                         final_tokens  \
# 0  [ardibhironx, protips, klik, gambar, jpeg, yan...
# 1  [tapi, bukankah, hidup, ini, adalah, perjuanga...
# 2  [sesedih, sedihnya, kisah, hidupmu, masih, leb...
# 3  [memperingati, tahun, naruto, ketika, beli, ef...
# 4  [orang, orang, tahunya, enak, banget, sih, hid...
# 5  [sepertinya, memang, perlu, menutup, diri, mak...
# 6                [therainband, akhirnya, di, notice]
# 7                                [kuntoajiw, gepeng]
# 8                     [alonkii, eh, gpu, deng, wkwk]
# 9                                     [alonkii, vga]
#
#                                               step02
# 0  ardibhironx protips klik gambar jpeg yang ters...
# 1       tapi bukankah hidup ini adalah perjuangan co
# 2  sesedih sedihnya kisah hidupmu masih lebih sed...
# 3  memperingati tahun naruto ketika beli efek git...
# 4  orang orang tahunya enak banget sih hidup lu t...
# 5  sepertinya memang perlu menutup diri makin ter...
# 6                     therainband akhirnya di notice
# 7                                   kuntoajiw gepeng
# 8                           alonkii eh gpu deng wkwk
# 9                                        alonkii vga

# %% [markdown]
# ## Simpan Clean Dataset

# %%
df_new.to_csv('clean_dataset_FiersaBesari')
